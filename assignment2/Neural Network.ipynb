# %% [markdown]
# # Задание 2.1 - Нейронные сети
#
# В этом задании вы реализуете и натренируете настоящую нейроную сеть своими руками!
#
# В некотором смысле это будет расширением прошлого задания - нам нужно просто составить несколько линейных классификаторов вместе!
#
# <img src="https://i.redd.it/n9fgba8b0qr01.png" alt="Stack_more_layers" width="400px"/>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from dataset import load_svhn, random_split_train_val
from gradient_check import check_layer_gradient, check_layer_param_gradient, check_model_gradient
from layers import FullyConnectedLayer, ReLULayer
from model import TwoLayerNet
from trainer import Trainer, Dataset
from optim import SGD, MomentumSGD
from metrics import multiclass_accuracy

# %% [markdown]
# # Загружаем данные
#
# И разделяем их на training и validation.

# %%
def prepare_for_neural_network(train_X, test_X):
    train_flat = train_X.reshape(train_X.shape[0], -1).astype(float) / 255.0
    test_flat = test_X.reshape(test_X.shape[0], -1).astype(float) / 255.0
    #test_X    = (1000, 32, 32, 3) - 1000 imgs 32x32 3 colors
    #test_flat = (1000, 3072)

    # Subtract mean
    mean_image = np.mean(train_flat, axis = 0) #is it mean of every pixel per 1000 imgs?

    train_flat -= mean_image #substract mean of every pixel per image
    test_flat -= mean_image
    
    return train_flat, test_flat
    
train_X, train_y, test_X, test_y = load_svhn("data", max_train=10000, max_test=1000)    
train_X, test_X = prepare_for_neural_network(train_X, test_X)
# Split train into train and val
train_X, train_y, val_X, val_y = random_split_train_val(train_X, train_y, num_val = 1000)

# %% [markdown]
# # Как всегда, начинаем с кирпичиков
#
# Мы будем реализовывать необходимые нам слои по очереди. Каждый слой должен реализовать:
# - прямой проход (forward pass), который генерирует выход слоя по входу и запоминает необходимые данные
# - обратный проход (baclkward pass), который получает градиент по выходу слоя и вычисляет градиент по входу и по параметрам
#
# Начнем с ReLU, у которого параметров нет.

# %%
# TODO: Implement ReLULayer layer in layers.py
# Note: you'll need to copy implementation of the gradient_check function from the previous assignment

X = np.array([[1,-2,3],
              [-1, 2, 0.1]])

assert check_layer_gradient(ReLULayer(), X)
# Out:
# Gradient check passed!

# %% [markdown]
# А теперь реализуем полносвязный слой (fully connected layer), у которого будет два массива параметров: W (weights) и B (bias).
#
# Все параметры наши слои будут использовать для параметров специальный класс `Param`, в котором будут храниться значения параметров и градиенты этих параметров, вычисляемые во время обратного прохода.
#
# Это даст возможность аккумулировать (суммировать) градиенты из разных частей функции потерь, например, из cross-entropy loss и regularization loss.

# %%
# TODO: Implement FullyConnected layer forward and backward methods
assert check_layer_gradient(FullyConnectedLayer(3, 4), X)
# TODO: Implement storing gradients for W and B
assert check_layer_param_gradient(FullyConnectedLayer(3, 4), X, 'W')
assert check_layer_param_gradient(FullyConnectedLayer(3, 4), X, 'B')
# Out:
# Gradient check passed!
# Gradient check passed!
# Gradient check passed!

# %% [markdown]
# ## Создаем нейронную сеть
#
# Теперь мы реализуем простейшую нейронную сеть с двумя полносвязным слоями и нелинейностью ReLU. Реализуйте функцию `compute_loss_and_gradients`, она должна запустить прямой и обратный проход через оба слоя для вычисления градиентов.
#
# Не забудьте реализовать очистку градиентов в начале функции.

# %%
# TODO: In model.py, implement compute_loss_and_gradients function
model = TwoLayerNet(n_input = train_X.shape[1], n_output = 10, hidden_layer_size = 3, reg = 0)
loss = model.compute_loss_and_gradients(train_X[:2], train_y[:2])

# TODO Now implement backward pass and aggregate all of the params
check_model_gradient(model, train_X[:2], train_y[:2], tol = 1e-3)
# Out:
# Checking gradient for l1W
# Gradient check passed!
# Checking gradient for l1B
# Gradient check passed!
# Checking gradient for l2W
# Gradient check passed!
# Checking gradient for l2B
# Gradient check passed!
# True

# %% [markdown]
# Теперь добавьте к модели регуляризацию - она должна прибавляться к loss и делать свой вклад в градиенты.

# %%
# TODO Now implement l2 regularization in the forward and backward pass
model_with_reg = TwoLayerNet(n_input = train_X.shape[1], n_output = 10, hidden_layer_size = 3, reg = 1e1)
loss_with_reg = model_with_reg.compute_loss_and_gradients(train_X[:2], train_y[:2])
assert loss_with_reg > loss and not np.isclose(loss_with_reg, loss), \
    "Loss with regularization (%2.4f) should be higher than without it (%2.4f)!" % (loss, loss_with_reg)

check_model_gradient(model_with_reg, train_X[:2], train_y[:2])
# Out:
# Checking gradient for l1W
# Gradient check passed!
# Checking gradient for l1B
# Gradient check passed!
# Checking gradient for l2W
# Gradient check passed!
# Checking gradient for l2B
# Gradient check passed!
# True

# %% [markdown]
# Также реализуем функцию предсказания (вычисления значения) модели на новых данных.
#
# Какое значение точности мы ожидаем увидеть до начала тренировки?

# %%
# Finally, implement predict function!

# TODO: Implement predict function
# What would be the value we expect?
multiclass_accuracy(model_with_reg.predict(train_X[:30]), train_y[:30])
# Out:
# 0.1

# %% [markdown]
# # Допишем код для процесса тренировки
#
# Если все реализовано корректно, значение функции ошибки должно уменьшаться с каждой эпохой, пусть и медленно. Не беспокойтесь пока про validation accuracy.

# %%
model = TwoLayerNet(n_input = train_X.shape[1], n_output = 10, hidden_layer_size = 100, reg = 1e-3)
dataset = Dataset(train_X, train_y, val_X, val_y)
trainer = Trainer(model, dataset, SGD(), learning_rate = 1e-2)

# TODO Implement missing pieces in Trainer.fit function
# You should expect loss to go down every epoch, even if it's slow
loss_history, train_history, val_history = trainer.fit()
# Out:
# Loss: 2.217622, Train accuracy: 0.196667, val accuracy: 0.206000
# Loss: 2.159229, Train accuracy: 0.196667, val accuracy: 0.206000
# Loss: 2.118454, Train accuracy: 0.196667, val accuracy: 0.206000
# Loss: 2.288418, Train accuracy: 0.196667, val accuracy: 0.206000
# Loss: 2.176193, Train accuracy: 0.196667, val accuracy: 0.206000
# Loss: 2.076980, Train accuracy: 0.196667, val accuracy: 0.206000
# Loss: 2.392960, Train accuracy: 0.196667, val accuracy: 0.206000
# Loss: 2.188526, Train accuracy: 0.196667, val accuracy: 0.206000
# Loss: 2.255413, Train accuracy: 0.196667, val accuracy: 0.206000
# Loss: 2.183981, Train accuracy: 0.196667, val accuracy: 0.206000
# Loss: 2.182781, Train accuracy: 0.196667, val accuracy: 0.206000
# Loss: 2.289347, Train accuracy: 0.196667, val accuracy: 0.206000
# Loss: 2.305080, Train accuracy: 0.196778, val accuracy: 0.206000
# Loss: 2.213488, Train accuracy: 0.202000, val accuracy: 0.209000
# Loss: 2.352644, Train accuracy: 0.242222, val accuracy: 0.247000
# Loss: 2.070942, Train accuracy: 0.258444, val accuracy: 0.264000
# Loss: 2.205725, Train accuracy: 0.273667, val accuracy: 0.278000
# Loss: 2.212915, Train accuracy: 0.286889, val accuracy: 0.288000
# Loss: 2.192269, Train accuracy: 0.300444, val accuracy: 0.301000
# Loss: 1.939974, Train accuracy: 0.326667, val accuracy: 0.326000

# %%
fig, axs = plt.subplots(2)
fig.set_size_inches(10, 6)

axs[0].plot(train_history)
axs[0].plot(val_history)
axs[0].grid()

axs[1].plot(loss_history)
axs[1].grid()

# %% [markdown]
# # Улучшаем процесс тренировки
#
# Мы реализуем несколько ключевых оптимизаций, необходимых для тренировки современных нейросетей.

# %% [markdown]
# ## Уменьшение скорости обучения (learning rate decay)
#
# Одна из необходимых оптимизаций во время тренировки нейронных сетей - постепенное уменьшение скорости обучения по мере тренировки.
#
# Один из стандартных методов - уменьшение скорости обучения (learning rate) каждые N эпох на коэффициент d (часто называемый decay). Значения N и d, как всегда, являются гиперпараметрами и должны подбираться на основе эффективности на проверочных данных (validation data).
#
# В нашем случае N будет равным 1.

# %%
# TODO Implement learning rate decay inside Trainer.fit method
# Decay should happen once per epoch

model = TwoLayerNet(n_input = train_X.shape[1], n_output = 10, hidden_layer_size = 100, reg = 1e-3)
dataset = Dataset(train_X, train_y, val_X, val_y)
trainer = Trainer(model, dataset, SGD(), learning_rate_decay=0.99, num_epochs = 50, learning_rate=1e-2)

initial_learning_rate = trainer.learning_rate
loss_history, train_history, val_history = trainer.fit()

assert trainer.learning_rate < initial_learning_rate, "Learning rate should've been reduced"
assert trainer.learning_rate > 0.5*initial_learning_rate, "Learning rate shouldn'tve been reduced that much!"
# Out:
# Loss: 2.294363, Train accuracy: 0.196667, val accuracy: 0.206000
# Loss: 2.345971, Train accuracy: 0.196667, val accuracy: 0.206000
# Loss: 2.264095, Train accuracy: 0.196667, val accuracy: 0.206000
# Loss: 2.230309, Train accuracy: 0.196667, val accuracy: 0.206000
# Loss: 2.221581, Train accuracy: 0.196667, val accuracy: 0.206000
# Loss: 2.246173, Train accuracy: 0.196667, val accuracy: 0.206000
# Loss: 2.210110, Train accuracy: 0.196667, val accuracy: 0.206000
# Loss: 2.346438, Train accuracy: 0.196667, val accuracy: 0.206000
# Loss: 2.368215, Train accuracy: 0.196667, val accuracy: 0.206000
# Loss: 2.401916, Train accuracy: 0.196667, val accuracy: 0.206000
# Loss: 2.308631, Train accuracy: 0.196667, val accuracy: 0.206000
# Loss: 2.256663, Train accuracy: 0.196667, val accuracy: 0.206000
# Loss: 2.048108, Train accuracy: 0.196667, val accuracy: 0.206000
# Loss: 2.045230, Train accuracy: 0.196889, val accuracy: 0.206000
# Loss: 2.104979, Train accuracy: 0.202556, val accuracy: 0.212000
# Loss: 2.128696, Train accuracy: 0.233111, val accuracy: 0.243000
# Loss: 2.089661, Train accuracy: 0.252111, val accuracy: 0.258000
# Loss: 2.146913, Train accuracy: 0.265333, val accuracy: 0.270000
# Loss: 2.078897, Train accuracy: 0.273778, val accuracy: 0.278000
# Loss: 2.159981, Train accuracy: 0.279556, val accuracy: 0.280000
# Loss: 2.135664, Train accuracy: 0.291222, val accuracy: 0.293000
# Loss: 1.895607, Train accuracy: 0.315333, val accuracy: 0.322000
# Loss: 1.786830, Train accuracy: 0.339889, val accuracy: 0.334000
# Loss: 1.590817, Train accuracy: 0.362444, val accuracy: 0.343000
# Loss: 1.941842, Train accuracy: 0.379222, val accuracy: 0.365000
# Loss: 1.698622, Train accuracy: 0.405000, val accuracy: 0.381000
# Loss: 1.762593, Train accuracy: 0.421333, val accuracy: 0.412000
# Loss: 1.636038, Train accuracy: 0.433778, val accuracy: 0.432000
# Loss: 1.756079, Train accuracy: 0.448444, val accuracy: 0.439000
# Loss: 1.452237, Train accuracy: 0.461000, val accuracy: 0.451000
# Loss: 1.434550, Train accuracy: 0.468778, val accuracy: 0.452000
# Loss: 1.468592, Train accuracy: 0.479111, val accuracy: 0.467000
# Loss: 1.415488, Train accuracy: 0.495889, val accuracy: 0.475000
# Loss: 1.469834, Train accuracy: 0.504222, val accuracy: 0.494000
# Loss: 1.588095, Train accuracy: 0.514667, val accuracy: 0.516000
# Loss: 1.605633, Train accuracy: 0.525222, val accuracy: 0.525000
# Loss: 1.774866, Train accuracy: 0.538222, val accuracy: 0.527000
# Loss: 1.374470, Train accuracy: 0.546778, val accuracy: 0.529000
# Loss: 1.435302, Train accuracy: 0.557889, val accuracy: 0.544000
# Loss: 1.544918, Train accuracy: 0.560333, val accuracy: 0.549000
# Loss: 1.055692, Train accuracy: 0.565333, val accuracy: 0.555000
# Loss: 1.160723, Train accuracy: 0.575667, val accuracy: 0.575000
# Loss: 1.191624, Train accuracy: 0.578889, val accuracy: 0.575000
# Loss: 1.642216, Train accuracy: 0.590444, val accuracy: 0.590000
# Loss: 1.243010, Train accuracy: 0.598556, val accuracy: 0.595000
# Loss: 1.502305, Train accuracy: 0.606556, val accuracy: 0.603000
# Loss: 1.027686, Train accuracy: 0.610778, val accuracy: 0.607000
# Loss: 1.351566, Train accuracy: 0.616222, val accuracy: 0.616000
# Loss: 1.501842, Train accuracy: 0.626333, val accuracy: 0.613000
# Loss: 1.907427, Train accuracy: 0.633333, val accuracy: 0.624000

# %%
fig, axs = plt.subplots(2)
fig.set_size_inches(10, 6)

axs[0].plot(train_history)
axs[0].plot(val_history)
axs[0].grid()

axs[1].plot(loss_history)
axs[1].grid()

# %% [markdown]
# # Накопление импульса (Momentum SGD)
#
# Другой большой класс оптимизаций - использование более эффективных методов градиентного спуска. Мы реализуем один из них - накопление импульса (Momentum SGD).
#
# Этот метод хранит скорость движения, использует градиент для ее изменения на каждом шаге, и изменяет веса пропорционально значению скорости.
# (Физическая аналогия: Вместо скорости градиенты теперь будут задавать ускорение, но будет присутствовать сила трения.)
#
# ```
# velocity = momentum * velocity - learning_rate * gradient
# w = w + velocity
# ```
#
# `momentum` здесь коэффициент затухания, который тоже является гиперпараметром (к счастью, для него часто есть хорошее значение по умолчанию, типичный диапазон -- 0.8-0.99).
#
# Несколько полезных ссылок, где метод разбирается более подробно:
# http://cs231n.github.io/neural-networks-3/#sgd
# https://distill.pub/2017/momentum/

# %%
# TODO: Implement MomentumSGD.update function in optim.py

model = TwoLayerNet(n_input = train_X.shape[1], n_output = 10, hidden_layer_size = 100, reg = 1e-3)
dataset = Dataset(train_X, train_y, val_X, val_y)
trainer = Trainer(model, dataset, MomentumSGD(), learning_rate=1e-2, learning_rate_decay=0.99)

# You should see even better results than before!
loss_history, train_history, val_history = trainer.fit()
# Out:
# Loss: 2.328040, Train accuracy: 0.196667, val accuracy: 0.206000
# Loss: 1.972371, Train accuracy: 0.293889, val accuracy: 0.304000
# Loss: 1.565527, Train accuracy: 0.467667, val accuracy: 0.485000
# Loss: 1.539601, Train accuracy: 0.571889, val accuracy: 0.563000
# Loss: 1.147776, Train accuracy: 0.636778, val accuracy: 0.630000
# Loss: 1.414143, Train accuracy: 0.656000, val accuracy: 0.641000
# Loss: 1.746150, Train accuracy: 0.675889, val accuracy: 0.667000
# Loss: 1.508917, Train accuracy: 0.704667, val accuracy: 0.682000
# Loss: 1.201793, Train accuracy: 0.708444, val accuracy: 0.676000
# Loss: 1.551286, Train accuracy: 0.717222, val accuracy: 0.686000
# Loss: 1.595432, Train accuracy: 0.717889, val accuracy: 0.703000
# Loss: 0.762916, Train accuracy: 0.742444, val accuracy: 0.687000
# Loss: 1.090430, Train accuracy: 0.752778, val accuracy: 0.702000
# Loss: 1.146103, Train accuracy: 0.754556, val accuracy: 0.711000
# Loss: 1.113435, Train accuracy: 0.756333, val accuracy: 0.699000
# Loss: 0.930471, Train accuracy: 0.771667, val accuracy: 0.728000
# Loss: 0.750616, Train accuracy: 0.773111, val accuracy: 0.728000
# Loss: 0.939088, Train accuracy: 0.743889, val accuracy: 0.676000
# Loss: 0.804529, Train accuracy: 0.783222, val accuracy: 0.719000
# Loss: 1.155585, Train accuracy: 0.785333, val accuracy: 0.698000

# %%
fig, axs = plt.subplots(2)
fig.set_size_inches(10, 6)

axs[0].plot(train_history)
axs[0].plot(val_history)
axs[0].grid()

axs[1].plot(loss_history)
axs[1].grid()

# %% [markdown]
# # Ну что, давайте уже тренировать сеть!

# %% [markdown]
# ## Последний тест - переобучимся (overfit) на маленьком наборе данных
#
# Хороший способ проверить, все ли реализовано корректно - переобучить сеть на маленьком наборе данных.
# Наша модель обладает достаточной мощностью, чтобы приблизить маленький набор данных идеально, поэтому мы ожидаем, что на нем мы быстро дойдем до 100% точности на тренировочном наборе.
#
# Если этого не происходит, то где-то была допущена ошибка!

# %%
data_size = 15
model = TwoLayerNet(n_input = train_X.shape[1], n_output = 10, hidden_layer_size = 100, reg = 1e-4)
dataset = Dataset(train_X[:data_size], train_y[:data_size], val_X[:data_size], val_y[:data_size])
trainer = Trainer(model, dataset, SGD(), learning_rate=1e-1, num_epochs=40, batch_size=2)

# You should expect this to reach 1.0 training accuracy 
loss_history, train_history, val_history = trainer.fit()
# Out:
# Loss: 2.274396, Train accuracy: 0.200000, val accuracy: 0.066667
# Loss: 2.400887, Train accuracy: 0.200000, val accuracy: 0.066667
# Loss: 2.432925, Train accuracy: 0.200000, val accuracy: 0.066667
# Loss: 2.457968, Train accuracy: 0.333333, val accuracy: 0.066667
# Loss: 2.273852, Train accuracy: 0.400000, val accuracy: 0.000000
# Loss: 1.720701, Train accuracy: 0.333333, val accuracy: 0.066667
# Loss: 0.911824, Train accuracy: 0.333333, val accuracy: 0.066667
# Loss: 2.469208, Train accuracy: 0.400000, val accuracy: 0.066667
# Loss: 2.478616, Train accuracy: 0.400000, val accuracy: 0.200000
# Loss: 2.505061, Train accuracy: 0.466667, val accuracy: 0.000000
# Loss: 1.362728, Train accuracy: 0.533333, val accuracy: 0.066667
# Loss: 1.597202, Train accuracy: 0.466667, val accuracy: 0.000000
# Loss: 0.600693, Train accuracy: 0.466667, val accuracy: 0.066667
# Loss: 2.392999, Train accuracy: 0.533333, val accuracy: 0.066667
# Loss: 0.033782, Train accuracy: 0.600000, val accuracy: 0.066667
# Loss: 2.365098, Train accuracy: 0.600000, val accuracy: 0.066667
# Loss: 0.024610, Train accuracy: 0.600000, val accuracy: 0.066667
# Loss: 2.299915, Train accuracy: 0.733333, val accuracy: 0.066667
# Loss: 2.012782, Train accuracy: 0.666667, val accuracy: 0.066667
# Loss: 2.385669, Train accuracy: 0.666667, val accuracy: 0.133333
# Loss: 1.856680, Train accuracy: 0.866667, val accuracy: 0.000000
# Loss: 1.596152, Train accuracy: 0.800000, val accuracy: 0.066667
# Loss: 0.270882, Train accuracy: 0.866667, val accuracy: 0.133333
# Loss: 1.377160, Train accuracy: 0.866667, val accuracy: 0.066667
# Loss: 0.105613, Train accuracy: 0.866667, val accuracy: 0.066667
# Loss: 0.003362, Train accuracy: 0.866667, val accuracy: 0.066667
# Loss: 2.182822, Train accuracy: 0.866667, val accuracy: 0.066667
# Loss: 0.006450, Train accuracy: 0.866667, val accuracy: 0.066667
# Loss: 0.078866, Train accuracy: 0.866667, val accuracy: 0.066667
# Loss: 0.002554, Train accuracy: 0.866667, val accuracy: 0.066667
# Loss: 0.042503, Train accuracy: 0.866667, val accuracy: 0.066667
# Loss: 0.051960, Train accuracy: 0.866667, val accuracy: 0.066667
# Loss: 0.003564, Train accuracy: 0.933333, val accuracy: 0.066667
# Loss: 1.817440, Train accuracy: 1.000000, val accuracy: 0.066667
# Loss: 0.004954, Train accuracy: 1.000000, val accuracy: 0.066667
# Loss: 0.183137, Train accuracy: 1.000000, val accuracy: 0.066667
# Loss: 0.059428, Train accuracy: 1.000000, val accuracy: 0.066667
# Loss: 0.011437, Train accuracy: 1.000000, val accuracy: 0.000000
# Loss: 0.021391, Train accuracy: 1.000000, val accuracy: 0.000000
# Loss: 0.003965, Train accuracy: 1.000000, val accuracy: 0.000000

# %%
fig, axs = plt.subplots(2)
fig.set_size_inches(10, 6)

axs[0].plot(train_history)
axs[0].plot(val_history)
axs[0].grid()

axs[1].plot(loss_history)
axs[1].grid()
#нормально так переобучились

# %% [markdown]
# Теперь найдем гипепараметры, для которых этот процесс сходится быстрее.
# Если все реализовано корректно, то существуют параметры, при которых процесс сходится в **20** эпох или еще быстрее.
# Найдите их!

# %%
# Now, tweak some hyper parameters and make it train to 1.0 accuracy in 20 epochs or less

model = TwoLayerNet(n_input = train_X.shape[1], n_output = 10, hidden_layer_size = 200, reg = 1e-4)
dataset = Dataset(train_X[:data_size], train_y[:data_size], val_X[:data_size], val_y[:data_size])
# TODO: Change any hyperparamers or optimizators to reach training accuracy in 20 epochs
trainer = Trainer(model, dataset, SGD(), learning_rate=1e-1+0.06, num_epochs=20, batch_size=2,learning_rate_decay=0.999)

loss_history, train_history, val_history = trainer.fit()

fig, axs = plt.subplots(2)
fig.set_size_inches(10, 6)

axs[0].plot(train_history)
axs[0].plot(val_history)
axs[0].grid()

axs[1].plot(loss_history)
axs[1].grid()
# Out:
# Loss: 2.413885, Train accuracy: 0.200000, val accuracy: 0.133333
# Loss: 2.310556, Train accuracy: 0.266667, val accuracy: 0.133333
# Loss: 2.095511, Train accuracy: 0.200000, val accuracy: 0.133333
# Loss: 2.638907, Train accuracy: 0.266667, val accuracy: 0.133333
# Loss: 2.561836, Train accuracy: 0.266667, val accuracy: 0.000000
# Loss: 2.485090, Train accuracy: 0.133333, val accuracy: 0.066667
# Loss: 2.520644, Train accuracy: 0.400000, val accuracy: 0.000000
# Loss: 2.431471, Train accuracy: 0.333333, val accuracy: 0.000000
# Loss: 1.645742, Train accuracy: 0.266667, val accuracy: 0.066667
# Loss: 2.519202, Train accuracy: 0.400000, val accuracy: 0.066667
# Loss: 1.044817, Train accuracy: 0.666667, val accuracy: 0.000000
# Loss: 0.214749, Train accuracy: 0.733333, val accuracy: 0.000000
# Loss: 0.105224, Train accuracy: 0.733333, val accuracy: 0.000000
# Loss: 0.012746, Train accuracy: 0.733333, val accuracy: 0.000000
# Loss: 0.039057, Train accuracy: 0.733333, val accuracy: 0.000000
# Loss: 2.607000, Train accuracy: 0.666667, val accuracy: 0.000000
# Loss: 0.033392, Train accuracy: 0.866667, val accuracy: 0.000000
# Loss: 0.468071, Train accuracy: 0.733333, val accuracy: 0.066667
# Loss: 0.006166, Train accuracy: 0.933333, val accuracy: 0.133333
# Loss: 2.011742, Train accuracy: 1.000000, val accuracy: 0.000000

# %% [markdown]
# # Итак, основное мероприятие!
#
# Натренируйте лучшую нейросеть! Можно добавлять и изменять параметры, менять количество нейронов в слоях сети и как угодно экспериментировать.
#
# Добейтесь точности лучше **60%** на validation set.

# %%
# Let's train the best one-hidden-layer network we can

learning_rates = 1e-2
reg_strength = 1e-3
learning_rate_decay = 0.99
hidden_layer_size = 128
num_epochs = 100
batch_size = 16

best_classifier = None
best_val_accuracy = None

dataset = Dataset(train_X, train_y, val_X, val_y)
model = TwoLayerNet(n_input = train_X.shape[1], n_output = 10, 
                                        hidden_layer_size = hidden_layer_size, 
                                        reg = reg_strength)

trainer = Trainer(model, dataset, MomentumSGD(), 
                                      num_epochs = num_epochs, 
                                      batch_size = batch_size, 
                                      learning_rate = learning_rates, 
                                      learning_rate_decay = learning_rate_decay)

loss_history, train_history, val_history = trainer.fit()

# TODO find the best hyperparameters to train the network
# Don't hesitate to add new values to the arrays above, perform experiments, use any tricks you want
# You should expect to get to at least 40% of valudation accuracy
# Save loss/train/history of the best classifier to the variables above

print('best validation accuracy achieved: %f' % max(val_history))
# Out:
# Loss: 2.305284, Train accuracy: 0.196667, val accuracy: 0.206000
# Loss: 2.287227, Train accuracy: 0.350444, val accuracy: 0.356000
# Loss: 2.032070, Train accuracy: 0.549889, val accuracy: 0.555000
# Loss: 1.109704, Train accuracy: 0.596333, val accuracy: 0.593000
# Loss: 0.460943, Train accuracy: 0.637778, val accuracy: 0.629000
# Loss: 1.007078, Train accuracy: 0.666222, val accuracy: 0.639000
# Loss: 1.162525, Train accuracy: 0.702333, val accuracy: 0.680000
# Loss: 2.052735, Train accuracy: 0.702333, val accuracy: 0.670000
# Loss: 1.596437, Train accuracy: 0.696667, val accuracy: 0.643000
# Loss: 0.768045, Train accuracy: 0.724444, val accuracy: 0.682000
# Loss: 0.905123, Train accuracy: 0.742000, val accuracy: 0.699000
# Loss: 0.828608, Train accuracy: 0.739889, val accuracy: 0.696000
# Loss: 1.001819, Train accuracy: 0.759333, val accuracy: 0.706000
# Loss: 1.373902, Train accuracy: 0.767556, val accuracy: 0.700000
# Loss: 0.754971, Train accuracy: 0.754444, val accuracy: 0.701000
# Loss: 1.900539, Train accuracy: 0.739889, val accuracy: 0.688000
# Loss: 0.400256, Train accuracy: 0.774556, val accuracy: 0.704000
# Loss: 1.114600, Train accuracy: 0.768222, val accuracy: 0.712000
# Loss: 0.557079, Train accuracy: 0.769778, val accuracy: 0.708000
# Loss: 0.973884, Train accuracy: 0.798333, val accuracy: 0.726000
# Loss: 1.282088, Train accuracy: 0.775000, val accuracy: 0.686000
# Loss: 0.760051, Train accuracy: 0.783444, val accuracy: 0.708000
# Loss: 1.316280, Train accuracy: 0.800000, val accuracy: 0.717000
# Loss: 1.523255, Train accuracy: 0.809889, val accuracy: 0.722000
# Loss: 0.811918, Train accuracy: 0.798778, val accuracy: 0.714000
# Loss: 1.004897, Train accuracy: 0.788000, val accuracy: 0.709000
# Loss: 0.551789, Train accuracy: 0.823111, val accuracy: 0.739000
# Loss: 0.617891, Train accuracy: 0.802667, val accuracy: 0.721000
# Loss: 1.296490, Train accuracy: 0.799333, val accuracy: 0.711000
# Loss: 1.235857, Train accuracy: 0.810111, val accuracy: 0.729000
# Loss: 0.588019, Train accuracy: 0.829667, val accuracy: 0.719000
# Loss: 1.066057, Train accuracy: 0.812222, val accuracy: 0.710000
# Loss: 0.812207, Train accuracy: 0.829778, val accuracy: 0.746000
# Loss: 0.915031, Train accuracy: 0.814667, val accuracy: 0.728000
# Loss: 1.095268, Train accuracy: 0.826667, val accuracy: 0.727000
# Loss: 0.663343, Train accuracy: 0.818333, val accuracy: 0.725000
# Loss: 1.104965, Train accuracy: 0.813333, val accuracy: 0.712000
# Loss: 0.661762, Train accuracy: 0.845000, val accuracy: 0.739000
# Loss: 0.969040, Train accuracy: 0.792000, val accuracy: 0.694000
# Loss: 1.501540, Train accuracy: 0.847889, val accuracy: 0.749000
# Loss: 0.934299, Train accuracy: 0.825333, val accuracy: 0.728000
# Loss: 1.528096, Train accuracy: 0.844667, val accuracy: 0.744000
# Loss: 0.705919, Train accuracy: 0.823778, val accuracy: 0.709000
# Loss: 1.551476, Train accuracy: 0.825111, val accuracy: 0.719000
# Loss: 0.959172, Train accuracy: 0.821111, val accuracy: 0.740000
# Loss: 1.358216, Train accuracy: 0.790000, val accuracy: 0.706000
# Loss: 0.579209, Train accuracy: 0.826444, val accuracy: 0.725000
# Loss: 2.366777, Train accuracy: 0.826889, val accuracy: 0.729000
# Loss: 1.169507, Train accuracy: 0.841333, val accuracy: 0.744000
# Loss: 0.440406, Train accuracy: 0.842889, val accuracy: 0.745000
# Loss: 0.860546, Train accuracy: 0.830444, val accuracy: 0.739000
# Loss: 0.615060, Train accuracy: 0.834889, val accuracy: 0.737000
# Loss: 0.736641, Train accuracy: 0.839111, val accuracy: 0.735000
# Loss: 1.291244, Train accuracy: 0.847222, val accuracy: 0.749000
# Loss: 0.784802, Train accuracy: 0.855889, val accuracy: 0.743000
# Loss: 1.008765, Train accuracy: 0.850778, val accuracy: 0.758000
# Loss: 0.868044, Train accuracy: 0.859889, val accuracy: 0.737000
# Loss: 1.543633, Train accuracy: 0.846444, val accuracy: 0.749000
# Loss: 0.866193, Train accuracy: 0.842556, val accuracy: 0.743000
# Loss: 0.926380, Train accuracy: 0.850111, val accuracy: 0.753000
# Loss: 0.644606, Train accuracy: 0.867444, val accuracy: 0.764000
# Loss: 0.918247, Train accuracy: 0.844333, val accuracy: 0.725000
# Loss: 0.616723, Train accuracy: 0.860556, val accuracy: 0.750000
# Loss: 0.626677, Train accuracy: 0.849889, val accuracy: 0.734000
# Loss: 0.430341, Train accuracy: 0.835778, val accuracy: 0.720000
# Loss: 0.739439, Train accuracy: 0.847222, val accuracy: 0.754000
# Loss: 0.741008, Train accuracy: 0.857556, val accuracy: 0.749000
# Loss: 0.836077, Train accuracy: 0.864667, val accuracy: 0.750000
# Loss: 0.742816, Train accuracy: 0.867556, val accuracy: 0.764000
# Loss: 1.131231, Train accuracy: 0.871889, val accuracy: 0.766000
# Loss: 0.621791, Train accuracy: 0.857000, val accuracy: 0.747000
# Loss: 1.113560, Train accuracy: 0.854333, val accuracy: 0.755000
# Loss: 0.581044, Train accuracy: 0.835444, val accuracy: 0.734000
# Loss: 0.596113, Train accuracy: 0.841222, val accuracy: 0.743000
# Loss: 1.020117, Train accuracy: 0.872778, val accuracy: 0.767000
# Loss: 0.663797, Train accuracy: 0.872889, val accuracy: 0.764000
# Loss: 0.926731, Train accuracy: 0.865333, val accuracy: 0.749000
# Loss: 0.874737, Train accuracy: 0.849444, val accuracy: 0.744000
# Loss: 0.434357, Train accuracy: 0.857222, val accuracy: 0.739000
# Loss: 1.106022, Train accuracy: 0.850333, val accuracy: 0.747000
# Loss: 1.396075, Train accuracy: 0.851556, val accuracy: 0.739000
# Loss: 0.849980, Train accuracy: 0.872222, val accuracy: 0.761000
# Loss: 0.897940, Train accuracy: 0.872333, val accuracy: 0.764000
# Loss: 0.871549, Train accuracy: 0.852000, val accuracy: 0.739000
# Loss: 1.110342, Train accuracy: 0.875222, val accuracy: 0.756000
# Loss: 0.909274, Train accuracy: 0.864333, val accuracy: 0.746000
# Loss: 1.072959, Train accuracy: 0.886000, val accuracy: 0.766000
# Loss: 1.456664, Train accuracy: 0.870222, val accuracy: 0.763000
# Loss: 1.240366, Train accuracy: 0.874444, val accuracy: 0.748000
# Loss: 1.022769, Train accuracy: 0.866111, val accuracy: 0.746000
# Loss: 0.554112, Train accuracy: 0.874444, val accuracy: 0.763000
# Loss: 0.504375, Train accuracy: 0.879222, val accuracy: 0.759000
# Loss: 1.103182, Train accuracy: 0.873222, val accuracy: 0.761000
# Loss: 1.079667, Train accuracy: 0.863556, val accuracy: 0.750000
# Loss: 0.925649, Train accuracy: 0.879000, val accuracy: 0.768000
# Loss: 0.854128, Train accuracy: 0.874778, val accuracy: 0.772000
# Loss: 0.523333, Train accuracy: 0.866889, val accuracy: 0.748000
# Loss: 0.765206, Train accuracy: 0.877667, val accuracy: 0.763000
# Loss: 0.666814, Train accuracy: 0.869222, val accuracy: 0.763000
# Loss: 0.923848, Train accuracy: 0.878222, val accuracy: 0.764000
# best validation accuracy achieved: 0.772000

# %%
fig, axs = plt.subplots(2)
fig.set_size_inches(10, 6)
axs[0].plot(train_history)
axs[0].plot(val_history)
axs[0].grid()

axs[1].plot(loss_history)
axs[1].grid()

# %% [markdown]
# # Как обычно, посмотрим, как наша лучшая модель работает на тестовых данных

# %%
test_pred = model.predict(test_X)
test_accuracy = multiclass_accuracy(test_pred, test_y)
print('Neural net test set accuracy: %f' % (test_accuracy, ))
# Out:
# Neural net test set accuracy: 0.740000
